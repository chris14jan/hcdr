# %% [markdown]
# **Hist_Gradient_Boost model functions**

# %% [markdown]
# # Imports

# %%
# packages
import pandas as pd
import numpy as np
import pickle
from sklearn.metrics import roc_auc_score, plot_roc_curve

# import functions
from hcdr.data.data import Data
from hcdr.modeling.preproc import preproc_pipeline
from hcdr.data.merged_data import merge_dfs

# import model
from sklearn.experimental import enable_hist_gradient_boosting   
from sklearn.ensemble import HistGradientBoostingClassifier

# %% [markdown]
# # Data

# %% [markdown]
# ## train data

# %%
def get_train_test_data():
    # preprocessor
    preproc = preproc_pipeline(scaler_type=None)
    
    # merge train dataframes
    df_merged = merge_dfs(df_app="application_train", verbose=True)
    df_merged = df_merged.replace(to_replace=np.inf,value=np.nan).replace(to_replace=-np.inf,value=np.nan)
    # define train variables
    X = df_merged.drop(columns=["SK_ID_CURR", "TARGET"])
    X_transformed = preproc.fit_transform(X)
    y = df_merged["TARGET"]
    
    # merge test dataframes
    df_test = merge_dfs(df_app="application_test", verbose=True)
    # define test variables
    df_test = df_test.replace(to_replace=np.inf,value=np.nan).replace(to_replace=-np.inf,value=np.nan)
    test = df_test.drop(columns=["SK_ID_CURR"])
    y_test = preproc.transform(test)
    
    return X_transformed, y, df_test, y_test

# %% [markdown]
# # HGB model

# %%
def hgb_model():
    
    # define variables
    # train data
    train_test = get_train_test_data() 
    X_transformed = train_test[0]
    y = train_test[1]
    # test data
    df_test = train_test[2]
    y_test = train_test[3]
    
    # instantiate model
    hgb = HistGradientBoostingClassifier(max_depth=15, max_iter = 20_000, scoring = 'roc_auc',verbose = 1)
    model_hgb = hgb.fit(X_transformed, y)
    
    # save final model to pickle file
    filename = 'finalized_hgb_model.sav'
    pickle.dump(model_hgb, open(filename, 'wb'))
    
    # run prediction
    hgb_pred = model_hgb.predict_proba(y_test)[:,1]
    
    # create submission file
    submit = df_test[['SK_ID_CURR']]
    submit['TARGET'] = hgb_pred
    
    # save submission file
    submit.to_csv('hgb_hcdr.csv',index=False)
    
    return submit.head()

# %%
# %%time
hgb_model()
# Out:
# Running preprocessor...
# scaler_type=None
# Aggregating non-application dataframes...
# application_train:       122 --> 72. Dropped 50 columns
# application_test:       121 --> 71. Dropped 50 columns
# previous_application:       37 --> 26. Dropped 11 columns
# Loading credit card balance data table...
# 23 --> 23. Dropped 0 columns
# optimized size by 26.0 % | 0.0103558 GB
# Loading 'bureau' AND 'bureau_balance' data tables...
# Running get_bureau_final function...
# Running get_bureau_balance_final function...
# optimized size by 65.99999999999999 % | 0.156472346 GB
# Loading isntallments payments data table...
# 8 --> 8. Dropped 0 columns
# optimized size by 19.999999999999996 % | 0.010866784 GB
# Loading POS_CASH_balance data table...
# 8 --> 8. Dropped 0 columns
# optimized size by 32.99999999999999 % | 0.010792064 GB
# application_train:       72 --> 72. Dropped 0 columns
# application_test:       71 --> 71. Dropped 0 columns
# previous_application:       26 --> 26. Dropped 0 columns
# credit_card_balance:       23 --> 16. Dropped 7 columns
# bureau:       505 --> 491. Dropped 14 columns
# installments_payments:       6 --> 6. Dropped 0 columns
# POS_CASH_balance:       6 --> 6. Dropped 0 columns
# Merging previous_application table ...
# Original shape: 307511, shape after merge: 307511
# Merging credit_card_balance table ...
# Original shape: 307511, shape after merge: 307511
# Merging bureau table ...
# Original shape: 307511, shape after merge: 307511
# Merging installments_payments table ...
# Original shape: 307511, shape after merge: 307511
# Merging POS_CASH_balance table ...
# Original shape: 307511, shape after merge: 307511
# Aggregating non-application dataframes...
# application_train:       122 --> 72. Dropped 50 columns
# application_test:       121 --> 71. Dropped 50 columns
# previous_application:       37 --> 26. Dropped 11 columns
# Loading credit card balance data table...
# 23 --> 23. Dropped 0 columns
# optimized size by 26.0 % | 0.0103558 GB
# Loading 'bureau' AND 'bureau_balance' data tables...
# Running get_bureau_final function...
# Running get_bureau_balance_final function...
# optimized size by 65.99999999999999 % | 0.156472346 GB
# Loading isntallments payments data table...
# 8 --> 8. Dropped 0 columns
# optimized size by 19.999999999999996 % | 0.010866784 GB
# Loading POS_CASH_balance data table...
# 8 --> 8. Dropped 0 columns
# optimized size by 32.99999999999999 % | 0.010792064 GB
# application_train:       72 --> 72. Dropped 0 columns
# application_test:       71 --> 71. Dropped 0 columns
# previous_application:       26 --> 26. Dropped 0 columns
# credit_card_balance:       23 --> 16. Dropped 7 columns
# bureau:       505 --> 491. Dropped 14 columns
# installments_payments:       6 --> 6. Dropped 0 columns
# POS_CASH_balance:       6 --> 6. Dropped 0 columns
# Merging previous_application table ...
# Original shape: 48744, shape after merge: 48744
# Merging credit_card_balance table ...
# Original shape: 48744, shape after merge: 48744
# Merging bureau table ...
# Original shape: 48744, shape after merge: 48744
# Merging installments_payments table ...
# Original shape: 48744, shape after merge: 48744
# Merging POS_CASH_balance table ...
# Original shape: 48744, shape after merge: 48744
# Binning 1.530 GB of training data: 12.047 s
# Binning 0.170 GB of validation data: 0.283 s
# Fitting gradient boosted rounds:
# [1/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.70430, val score: 0.70838, in 0.576s
# [2/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.71312, val score: 0.71466, in 0.445s
# [3/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.71769, val score: 0.71692, in 0.412s
# [4/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.72151, val score: 0.72122, in 0.407s
# [5/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.72281, val score: 0.72369, in 0.430s
# [6/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.72599, val score: 0.72555, in 0.421s
# [7/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.72926, val score: 0.72794, in 0.404s
# [8/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.73132, val score: 0.73003, in 0.457s
# [9/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.73297, val score: 0.73121, in 0.426s
# [10/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.73581, val score: 0.73292, in 0.418s
# [11/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.73963, val score: 0.73436, in 0.400s
# [12/20000] 1 tree, 31 leaves, max depth = 11, train score: 0.74101, val score: 0.73552, in 0.421s
# [13/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.74333, val score: 0.73713, in 0.458s
# [14/20000] 1 tree, 31 leaves, max depth = 11, train score: 0.74409, val score: 0.73828, in 0.430s
# [15/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.74601, val score: 0.74000, in 0.418s
# [16/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.74740, val score: 0.74096, in 0.429s
# [17/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.74925, val score: 0.74223, in 0.423s
# [18/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.75116, val score: 0.74357, in 0.434s
# [19/20000] 1 tree, 31 leaves, max depth = 10, train score: 0
20000] 1 tree, 31 leaves, max depth = 11, train score: 0.79802, val score: 0.76759, in 0.466s
# [76/20000] 1 tree, 31 leaves, max depth = 11, train score: 0.79828, val score: 0.76785, in 0.406s
# [77/20000] 1 tree, 31 leaves, max depth = 13, train score: 0.79844, val score: 0.76784, in 0.456s
# [78/20000] 1 tree, 31 leaves, max depth = 14, train score: 0.79879, val score: 0.76781, in 0.395s
# [79/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.79930, val score: 0.76794, in 0.402s
# [80/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.79986, val score: 0.76796, in 0.474s
# [81/20000] 1 tree, 31 leaves, max depth = 13, train score: 0.80026, val score: 0.76802, in 0.445s
# [82/20000] 1 tree, 31 leaves, max depth = 11, train score: 0.80040, val score: 0.76814, in 0.437s
# [83/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.80080, val score: 0.76830, in 0.410s
# [84/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.80161, val score: 0.76818, in 0.335s
# [85/20000] 1 tree, 31 leaves, max depth = 15, train score: 0.80249, val score: 0.76814, in 0.399s
# [86/20000] 1 tree, 31 leaves, max depth = 11, train score: 0.80304, val score: 0.76822, in 0.384s
# [87/20000] 1 tree, 31 leaves, max depth = 15, train score: 0.80312, val score: 0.76813, in 0.359s
# [88/20000] 1 tree, 31 leaves, max depth = 14, train score: 0.80327, val score: 0.76828, in 0.394s
# [89/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.80357, val score: 0.76824, in 0.379s
# [90/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.80385, val score: 0.76843, in 0.425s
# [91/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.80393, val score: 0.76846, in 0.447s
# [92/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.80443, val score: 0.76854, in 0.434s
# [93/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.80450, val score: 0.76855, in 0.349s
# [94/20000] 1 tree, 31 leaves, max depth = 13, train score: 0.80486, val score: 0.76854, in 0.467s
# [95/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.80538, val score: 0.76848, in 0.333s
# [96/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.80574, val score: 0.76863, in 0.434s
# [97/20000] 1 tree, 31 leaves, max depth = 8, train score: 0.80641, val score: 0.76849, in 0.356s
# [98/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.80702, val score: 0.76863, in 0.383s
# [99/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.80743, val score: 0.76875, in 0.504s
# [100/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.80775, val score: 0.76881, in 0.451s
# [101/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.80779, val score: 0.76880, in 0.333s
# [102/20000] 1 tree, 31 leaves, max depth = 11, train score: 0.80798, val score: 0.76879, in 0.364s
# [103/20000] 1 tree, 31 leaves, max depth = 14, train score: 0.80837, val score: 0.76882, in 0.439s
# [104/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.80860, val score: 0.76875, in 0.374s
# [105/20000] 1 tree, 31 leaves, max depth = 9, train score: 0.80885, val score: 0.76867, in 0.361s
# [106/20000] 1 tree, 31 leaves, max depth = 14, train score: 0.80936, val score: 0.76862, in 0.425s
# [107/20000] 1 tree, 31 leaves, max depth = 13, train score: 0.81004, val score: 0.76859, in 0.376s
# [108/20000] 1 tree, 31 leaves, max depth = 10, train score: 0.81023, val score: 0.76862, in 0.383s
# [109/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.81063, val score: 0.76855, in 0.358s
# [110/20000] 1 tree, 31 leaves, max depth = 11, train score: 0.81103, val score: 0.76850, in 0.368s
# [111/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.81217, val score: 0.76860, in 0.374s
# [112/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.81265, val score: 0.76860, in 0.387s
# [113/20000] 1 tree, 31 leaves, max depth = 12, train score: 0.81304, val score: 0.76878, in 0.457s
# Fit 113 trees in 61.476 s, (3503 total leaves)
# Time spent computing histograms: 19.757s
# Time spent finding best splits:  1.168s
# Time spent applying splits:      1.105s
# Time spent predicting:           0.050s
# CPU times: user 9min 7s, sys: 1min 44s, total: 10min 51s
# Wall time: 5min 57s
# <ipython-input-40-9c1c7d6c65d9>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['TARGET'] = hgb_pred
#    SK_ID_CURR    TARGET
# 0      100001  0.056121
# 1      100005  0.276784
# 2      100013  0.036606
# 3      100028  0.055429
# 4      100038  0.167401
