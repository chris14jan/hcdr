# %% [markdown]
# # Installments Payments & POS Cash Balance DF

# %%
from hcdr.data.data import Data

# %%
# %%time
dfs = Data().get_data()
# Out:
# CPU times: user 29.8 s, sys: 3.37 s, total: 33.1 s
# Wall time: 33.7 s

# %%
install_payments_df = Data().get_data(tables=["installments_payments"])["installments_payments"]

# %%
print("Length:")
print("before:", install_payments_df.shape[0], "groupby:", install_payments_df.groupby("SK_ID_CURR").count().shape[0])
# Out:
# Length:
# before: 13605401 groupby: 339587

# %%
install_payments_df
# Out:
#           SK_ID_PREV  SK_ID_CURR  NUM_INSTALMENT_VERSION  \
# 0            1054186      161674                     1.0
# 1            1330831      151639                     0.0
# 2            2085231      193053                     2.0
# 3            2452527      199697                     1.0
# 4            2714724      167756                     1.0
# ...              ...         ...                     ...
# 13605396     2186857      428057                     0.0
# 13605397     1310347      414406                     0.0
# 13605398     1308766      402199                     0.0
# 13605399     1062206      409297                     0.0
# 13605400     2448869      434321                     1.0
#
#           NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  DAYS_ENTRY_PAYMENT  \
# 0                             6          -1180.0             -1187.0
# 1                            34          -2156.0             -2156.0
# 2                             1            -63.0               -63.0
# ...

# %%
columns_to_drop = ["NUM_INSTALMENT_VERSION"]

# %%
install_payments_df = install_payments_df.drop(columns=columns_to_drop)

# %%
install_payments_df.groupby("SK_ID_CURR").agg("mean")
# Out:
#               SK_ID_PREV  NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  \
# SK_ID_CURR
# 100001      1.576389e+06               2.714286     -2187.714355
# 100002      1.038818e+06              10.000000      -295.000000
# 100003      2.290070e+06               5.080000     -1378.160034
# 100004      1.564014e+06               2.000000      -754.000000
# 100005      2.495675e+06               5.000000      -586.000000
# ...                  ...                    ...              ...
# 456251      2.248017e+06               4.000000      -120.000000
# 456252      1.503599e+06               3.500000     -2391.000000
# 456253      1.753310e+06               4.785714     -2372.928467
# 456254      1.898777e+06               5.263158      -142.263153
# 456255      1.969824e+06               8.851351      -463.945953
#
#             DAYS_ENTRY_PAYMENT  AMT_INSTALMENT   AMT_PAYMENT
# SK_ID_CURR
# 100001            -2195.000000     5885.132324   5885.132324
# ...

# %%
def preprocess_installments_df(agg="mean"): 
    installments_payments_df = Data().get_data(tables=["installments_payments"])["installments_payments"]
    
    columns_to_drop = ["NUM_INSTALMENT_VERSION"]
    installments_payments_df = installments_payments_df.drop(columns=columns_to_drop)
    
    grouped_df = install_payments_df.groupby("SK_ID_CURR").agg(agg)
    
    return grouped_df

# %%
preprocess_installments_df()
# Out:
#               SK_ID_PREV  NUM_INSTALMENT_NUMBER  DAYS_INSTALMENT  \
# SK_ID_CURR
# 100001      1.576389e+06               2.714286     -2187.714355
# 100002      1.038818e+06              10.000000      -295.000000
# 100003      2.290070e+06               5.080000     -1378.160034
# 100004      1.564014e+06               2.000000      -754.000000
# 100005      2.495675e+06               5.000000      -586.000000
# ...                  ...                    ...              ...
# 456251      2.248017e+06               4.000000      -120.000000
# 456252      1.503599e+06               3.500000     -2391.000000
# 456253      1.753310e+06               4.785714     -2372.928467
# 456254      1.898777e+06               5.263158      -142.263153
# 456255      1.969824e+06               8.851351      -463.945953
#
#             DAYS_ENTRY_PAYMENT  AMT_INSTALMENT   AMT_PAYMENT
# SK_ID_CURR
# 100001            -2195.000000     5885.132324   5885.132324
# ...

# %% [markdown]
# ## POS CASH balance df

# %%
POS_CASH_balance_df = Data().get_data(tables=["POS_CASH_balance"])["POS_CASH_balance"]

# %%
columns_to_drop = []
POS_CASH_balance_df = POS_CASH_balance_df.drop(columns= columns_to_drop)

# %%
POS_CASH_balance_df
# Out:
#           SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0            1803195      182943             -31            48.0
# 1            1715348      367990             -33            36.0
# 2            1784872      397406             -32            12.0
# 3            1903291      269225             -35            48.0
# 4            2341044      334279             -35            36.0
# ...              ...         ...             ...             ...
# 10001353     2448283      226558             -20             6.0
# 10001354     1717234      141565             -19            12.0
# 10001355     1283126      315695             -21            10.0
# 10001356     1082516      450255             -22            12.0
# 10001357     1259607      174278             -52            16.0
#
#           CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                          45.0               Active       0           0
# ...

# %%
POS_CASH_balance_df.groupby("SK_ID_CURR").agg("mean")
# Out:
#               SK_ID_PREV  MONTHS_BALANCE  CNT_INSTALMENT  \
# SK_ID_CURR
# 100001      1.584045e+06      -72.555556        4.000000
# 100002      1.038818e+06      -10.000000       24.000000
# 100003      2.297665e+06      -43.785714       10.107142
# 100004      1.564014e+06      -25.500000        3.750000
# 100005      2.495675e+06      -20.000000       11.700000
# ...                  ...             ...             ...
# 456251      2.248017e+06       -5.000000        7.875000
# 456252      1.503599e+06      -79.000000        6.000000
# 456253      1.760593e+06      -79.235294        6.705883
# 456254      1.893484e+06       -5.550000       14.900000
# 456255      1.951191e+06      -16.408451       22.788733
#
#             CNT_INSTALMENT_FUTURE    SK_DPD  SK_DPD_DEF
# SK_ID_CURR
# 100001                   1.444444  0.777778    0.777778
# 100002                  15.000000  0.000000    0.000000
# 100003                   5.785714  0.000000    0.000000
# ...
